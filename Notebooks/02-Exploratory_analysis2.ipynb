# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS**
#
# ---
#
#
#
# The goal of this notebook is to perform Exploratory Data Analysis to better understand the data.

# %% [markdown]
# ###**Dataset Description**
#
# The data provided is text data that has 6 columns with 404290 rows.
#
# Below are the variables in our dataset:
#
# • **id** - the id of a training set question pair
#
# •	**qid1, qid2** - unique ids of each question (only available in train.csv)
#
# •	**question1, question2** - the full text of each question
#
# •	**is_duplicate** - the target variable, set to 1 if question1 and question2 have essentially the same meaning, and 0 otherwise.

# %%
# Import Libraries

import pandas as pd
import numpy as np

from nltk.util import ngrams
from collections import  Counter
from sklearn.feature_extraction.text import CountVectorizer 

import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
colors = ['firebrick', 'tomato']
 
import warnings
warnings.filterwarnings('ignore')

# %%
# Load data

url = 'https://github.com/Koorimikiran369/Quora-Question-Pairing/raw/main/train.csv.zip'

df = pd.read_csv(url, compression='zip')
df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
df = df.drop('id', axis=1)

# %%
print("Shape of the data: ", df.shape)
# Out:
# Shape of the data:  (404290, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   qid1          404290 non-null  int64
#  1   qid2          404290 non-null  int64
#  2   question1     404289 non-null  object
#  3   question2     404288 non-null  object
#  4   is_duplicate  404290 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 15.4+ MB

# %%
# Check null values

df.isna().sum()
# Out:
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64

# %%
# Print null values

nan = df[df.isna().any(1)]
print(nan)
# Out:
#           qid1    qid2                         question1  \
# 105780  174363  174364    How can I develop android app?
# 201841  303951  174364  How can I create an Android app?
# 363362  493340  493341                               NaN
#
#                                                 question2  is_duplicate
# 105780                                                NaN             0
# 201841                                                NaN             0
# 363362  My Chinese name is Haichao Yu. What English na...             0

# %% [markdown]
# qid2 has 2 null rows with the same qid

# %%
# Filtering rows by question ids of nulls

target_ids = [174364,493340] 

mask_qid1 = df['qid1'].isin(target_ids)
mask_qid2 = df['qid2'].isin(target_ids)

# Filter rows based on the question IDs in either column qid1 or qid2
filtered_rows = df[mask_qid1 | mask_qid2]

print(filtered_rows)
# Out:
#           qid1    qid2                         question1  \
# 105780  174363  174364    How can I develop android app?
# 201841  303951  174364  How can I create an Android app?
# 363362  493340  493341                               NaN
#
#                                                 question2  is_duplicate
# 105780                                                NaN             0
# 201841                                                NaN             0
# 363362  My Chinese name is Haichao Yu. What English na...             0

# %% [markdown]
# There are no other questions with the same question ids to replace the null values with. We can drop these rows since there are only 3 null values.

# %%
# Drop rows with null values

df.dropna(inplace=True)
df.shape
# Out:
# (404287, 5)

# %%
# Check duplicate values
 
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Target Variable**

# %%
# Target variable distribution

df['is_duplicate'].value_counts()
# Out:
# 0    255024
# 1    149263
# Name: is_duplicate, dtype: int64

# %%
# Visualizing the target distribution

plt.figure(figsize=(8, 6))
sns.countplot(x='is_duplicate', data=df, palette=colors)
plt.xlabel('Is Duplicate')
plt.ylabel('Count')

# Calculate the percentage for each category
total_count = len(df)
counts = df['is_duplicate'].value_counts()
for i, count in enumerate(counts):
    percentage = (count / total_count) * 100
    plt.text(i, count, f'{percentage:.2f}%', ha='center', va='bottom')

plt.show()

# %% [markdown]
# There are 63.08% non-duplicates and 36.92% duplicates indicating imbalance.

# %%
# Check the number of unique questions

qids = pd.Series(df['qid1'].tolist() + df['qid2'].tolist())
unique_qns = len(np.unique(qids))
rep_qns = np.sum(qids.value_counts() > 1)

print ('Number of  unique Questions are: {}\n'.format(unique_qns))
print ('Number of unique questions that appear more than one time: {} ({:.2f}%)\n'.format(rep_qns, rep_qns/unique_qns*100))
# Out:
# Number of  unique Questions are: 537929
#
# Number of unique questions that appear more than one time: 111778 (20.78%)

# %%
# Print the top 10 most repeated questions

questions = pd.Series(df['question1'].tolist() + df['question2'].tolist())
repeated_questions = questions[qids.duplicated(keep=False)]

# Count occurrences of each question
question_counts = repeated_questions.value_counts()

# Sort questions based on occurrence count in descending order
top_10_questions = question_counts.head(10)
top_10_questions
# Out:
# What are the best ways to lose weight?                                                                159
# How can you look at someone's private Instagram account without following them?                       120
# How can I lose weight quickly?                                                                        111
# What's the easiest way to make money online?                                                           88
# Can you see who views your Instagram?                                                                  79
# What are some things new employees should know going into their first day at AT&T?                     77
# What do you think of the decision by the Indian Government to demonetize 500 and 1000 rupee notes?     68
# Which is the best digital marketing course?                                                            66
# How can you increase your height?                                                                      63
# How do l see who viewed my videos on Instagram?                                                        61
# dtype: int64

# %%
# Plot the number of occurrences of questions

plt.figure(figsize=(20, 5))
sns.histplot(qids.value_counts(), bins=160,log_scale=(False, True), color = 'firebrick')
plt.xlim((1, 162))
plt.title('Log-Histogram of Question Appearance Counts')
plt.xlabel("Number of Occurrences of Questions")
plt.ylabel("Number of Questions")

plt.show()

# %% [markdown]
# ## **Text Statistics**

# %%
# Compute question lengths

def compute_lengths(df):
    df['question1_len'] = df['question1'].str.len()
    df['question2_len'] = df['question2'].str.len()
    df['question_len_diff'] = abs(df['question1_len'] - df['question2_len'])
    
    return df

df = compute_lengths(df)

# %%
# Display summary statistics

print("Summary Statistics:")
print(df[['question1_len', 'question2_len', 'question_len_diff']].describe())
# Out:
# Summary Statistics:
#        question1_len  question2_len  question_len_diff
# count  404287.000000  404287.000000      404287.000000
# mean       59.536997      60.108507          20.157893
# std        29.940553      33.863588          25.584008
# min         1.000000       1.000000           0.000000
# 25%        39.000000      39.000000           4.000000
# 50%        52.000000      51.000000          12.000000
# 75%        72.000000      72.000000          26.000000
# max       623.000000    1169.000000        1080.000000

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot 'question1_len'
axes[0].hist(df['question1_len'], bins=20, color='tomato')
axes[0].set_xlabel('Question 1 Length')
axes[0].set_ylabel('Frequency')

# Plot 'question2_len'
axes[1].hist(df['question2_len'], bins=20, color='firebrick')
axes[1].set_xlabel('Question 2 Length')
axes[1].set_ylabel('Frequency')

# Plot 'question_len_diff'
axes[2].hist(df['question_len_diff'], bins=20, color='tomato')
axes[2].set_xlabel('Question Length Difference')
axes[2].set_ylabel('Frequency')

# Adjust the spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Printing one word rows

one_len_rows = df[(df['question1_len'] == 1) | (df['question2_len'] == 1)]

print(len(one_len_rows))
one_len_rows
# Out:
# 21
#           qid1    qid2                                          question1  \
# 3306      6553    6554                                                  .
# 13016    25026   25027                                                  ?
# 20794    39204   39205                                                  ?
# 47056    84067   84068  Is there anywhere in the world offering pain m...
# 96725   161071  161072                                                  ?
# 104101  171925  171926                                                  ?
# 108978  178936  178937                                                  i
# 115347  188110   52215                                                  o
# 134403  214814  214815                                                  ?
# 151922  188110  238787                                                  o
# 158778  247989   48850                                                  A
# 189659  161071  288480                                                  ?
# 190570  289688  289689                                                  ‘
# 198913  300250  188110                                      What is this?
# 199110  300509  300510                                                  I
# 208485  312495  312496                                                  ?
# 213220   25026   64784                                                  ?
# 254161  214814  368834                                                  ?
# 273065  391451  380455                                                  ?
# 357127  486520  146954                                                  H
# 402423  535899  119568                                                  ?
#
#                                                 question2  is_duplicate  \
# 3306    Why is Cornell's endowment the lowest in the I...             0
# 13016                  Why should one not work at Google?             0
# 20794   What is the Gmail tech support help phone number?             0
# 47056                                                   ?             0
# 96725                     Who are Moses, Noah and Exodus?             0
# 104101  Problem of solving a problem is not a problem,...             0
# 108978                What questions to ask any drdummer?             0
# 115347    Where can I watch free streaming movies online?             0
# 134403  What is your take on the undercover report tha...             0
# 151922  What is this - “This website/URL has been bloc...             0
# 158778  Do men forgive their wives when they cheat on ...             0
# 189659                                       Who is Noah?             0
# 190570  Time is money.Can some one explain, how it works?             0
# 198913                                                  o             0
# 199110  What is the connection between Donald trump an...             0
# 208485  Given that PACER makes money from usage, why d...             0
# 213220                 What is it like to work at Google?             0
# 254161  How do I convince my non-Indian friends that n...             0
# 273065  How can I describe Quora, in all its glory, to...             0
# 357127                      Should I forgive the cheater?             0
# 402423  What is cisco router technical support phone n...             0
#
#         question1_len  question2_len  question_len_diff
# 3306                1             56                 55
# 13016               1             34                 33
# 20794               1             49                 48
# 47056             117              1                116
# 96725               1             31                 30
# 104101              1            149                148
# 108978              1             35                 34
# 115347              1             47                 46
# 134403              1            144                143
# 151922              1            132                131
# 158778              1             51                 50
# 189659              1             12                 11
# 190570              1             49                 48
# 198913             13              1                 12
# 199110              1             69                 68
# 208485              1            101                100
# 213220              1             34                 33
# 254161              1            140                139
# 273065              1             55                 54
# 357127              1             29                 28
# 402423              1             52                 51

# %% [markdown]
# The rows with length 1 comprise of letters and special characters. These rows will not be helpful for the question similarity problem.

# %%
# Drop the rows with one-word questions

df = df.drop(one_len_rows.index)
df.shape
# Out:
# (404266, 8)

# %% [markdown]
# **Average word length in a question**

# %%
df['question1'].str.split().apply(lambda x : [len(i) for i in x]).map(lambda x: np.mean(x)).hist(color = 'firebrick');

# %%
df['question2'].str.split().apply(lambda x : [len(i) for i in x]).map(lambda x: np.mean(x)).hist(color = 'firebrick');

# %% [markdown]
# **Word Cloud**

# %%
# Generate world clouds for 'question1' and 'question2' for the train dataset 
question1_text = ' '.join(df['question1'])
question2_text = ' '.join(df['question2'])

wordcloud1 = WordCloud(width=800, height=400, background_color='white', colormap='Reds').generate(question1_text)
wordcloud2 = WordCloud(width=800, height=400, background_color='white', colormap='Reds').generate(question2_text)

# Plot word clouds
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
plt.imshow(wordcloud1, interpolation='bilinear')
plt.title('Word Cloud  - question1(Train)')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(wordcloud2, interpolation='bilinear')
plt.title('Word Cloud - question2(Train)')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Top n-grams**

# %%
def plot_top_ngrams_barchart(text, n=2):
  
    new= text.str.split()
    new=new.values.tolist()
    corpus=[word for i in new for word in i]

    def _get_top_ngram(corpus, n=None):
        vec = CountVectorizer(ngram_range=(n, n)).fit(corpus)
        bag_of_words = vec.transform(corpus)
        sum_words = bag_of_words.sum(axis=0) 
        words_freq = [(word, sum_words[0, idx]) 
                      for word, idx in vec.vocabulary_.items()]
        words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
        return words_freq[:10]

    top_n_bigrams=_get_top_ngram(text,n)[:10]
    x,y=map(list,zip(*top_n_bigrams))
    sns.barplot(x=y,y=x, palette='Reds')

# %%
plot_top_ngrams_barchart(df['question1'],2)

# %%
plot_top_ngrams_barchart(df['question2'],2)

# %%
plot_top_ngrams_barchart(df['question1'],3)

# %%
plot_top_ngrams_barchart(df['question2'],3)

# %%
df.to_csv('cleaned_data.csv', index = False)
